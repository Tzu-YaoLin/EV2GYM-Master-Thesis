# %%
#Install the required packages
# %pip install wandb stable-baselines3 gymnasium matplotlib torch
# Out:
# ...
#   Using cached wandb-0.19.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# ...
#   Using cached stable_baselines3-2.4.1-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached sentry_sdk-2.20.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached setproctitle-1.3.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# ...
#   Using cached gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# ...
# Using cached wandb-0.19.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.3 MB)
# Using cached stable_baselines3-2.4.1-py3-none-any.whl (183 kB)
# Using cached gymnasium-1.0.0-py3-none-any.whl (958 kB)
# Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Using cached sentry_sdk-2.20.0-py2.py3-none-any.whl (322 kB)
# ...

# %%
# %restart_python

# %%
import os
import torch
import wandb
import gymnasium as gym
from stable_baselines3 import A2C
from ev2gym.rl_agent.reward import profit_maximization
from ev2gym.rl_agent.state import V2G_profit_max
from stable_baselines3.common.noise import NormalActionNoise


# Set WandB API key
os.environ["WANDB_API_KEY"] = "e09f1372cfe6ed2cd13773350fe920cb084c6341"  # Replace with your API Key

# Set device
device = 'cpu'
print(f"Using device: {device}")
# Out:
# 2025-01-22 03:19:37.206328: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737515977.226792  168354 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737515977.233302  168354 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-22 03:19:37.254089: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cpu

# %%
import wandb
wandb.agent('extern-tzu-yao-lin-cariad/ev2gym_a2c_tuning/llvessf2')
# Out:
# 2025-01-22 03:19:47,701 - wandb.wandb_agent - INFO - Running runs: []
# INFO:wandb.wandb_agent:Running runs: []
# 2025-01-22 03:19:47,961 - wandb.wandb_agent - INFO - Agent received command: run
# INFO:wandb.wandb_agent:Agent received command: run
# 2025-01-22 03:19:47,962 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	ent_coef: 0.0147990803120188
# 	gae_lambda: 0.9255269983675336
# 	gamma: 0.9711832403852252
# 	learning_rate: 0.0006149986425561727
# 	max_grad_norm: 3.0519485168609717
# 	n_steps: 128
# 	policy_type: MlpPolicy
# 	total_timesteps: 350400
# 	vf_coef: 0.7232332505350847
# INFO:wandb.wandb_agent:Agent starting run with config:
# 	ent_coef: 0.0147990803120188
# 	gae_lambda: 0.9255269983675336
# 	gamma: 0.9711832403852252
# 	learning_rate: 0.0006149986425561727
# 	max_grad_norm: 3.0519485168609717
# 	n_steps: 128
# 	policy_type: MlpPolicy
# 	total_timesteps: 350400
# 	vf_coef: 0.7232332505350847
# ...
